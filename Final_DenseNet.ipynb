# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import DenseNet201
from tensorflow.keras.layers import Dropout, Dense, GlobalAveragePooling2D, Conv2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.activations import swish
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
df = pd.read_csv("DataSet/HAM.csv")
df['image_id'] = df['image_id'].apply(lambda x: x + ".jpg")
class_counts = df['dx'].value_counts()

# Print the counts for each class
print(class_counts)
# Out:
# dx
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: count, dtype: int64

# %%
# Define image dimensions and batch size
img_size = (100, 100)
batch_size = 16

# Create data generators for augmentation
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)

# %%
train_df, test_valid_df = train_test_split(df, test_size=0.3, random_state=42)
test_df, valid_df = train_test_split(test_valid_df, test_size=0.5, random_state=42)
train_df['image_id'] = 'DataSet/Combined/' + train_df['image_id']
valid_df['image_id'] = 'DataSet/Combined/' + valid_df['image_id']
test_df['image_id'] = 'DataSet/Combined/' + test_df['image_id']

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)

valid_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    train_df,
    x_col='image_id',
    y_col='dx',
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

valid_generator = valid_datagen.flow_from_dataframe(
    valid_df,
    x_col='image_id',
    y_col='dx',
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(
    test_df,
    x_col='image_id',
    y_col='dx',
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 7010 validated image filenames belonging to 7 classes.
# Found 1503 validated image filenames belonging to 7 classes.
# Found 1502 validated image filenames belonging to 7 classes.

# %%
base_model = DenseNet201(weights='imagenet', include_top=False, input_shape=(img_size[0], img_size[1], 3))



x = base_model.output
x = Conv2D(64, (3, 3), activation='relu')(x)
x = BatchNormalization()(x)
x = GlobalAveragePooling2D()(x)

x = Dropout(0.5)(x)
x = Dense(1024, activation=swish)(x)
x = Dropout(0.5)(x)
x = Dense(256, activation=swish)(x)
x = Dropout(0.5)(x)

predictions = Dense(7, activation='softmax')(x)  # Replace NUM_CLASSES with the number of classes

model = Model(inputs=base_model.input, outputs=predictions)

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=150,  # You can adjust the number of epochs
    steps_per_epoch=len(train_generator),
    validation_steps=len(valid_generator)
)
# Out:
# Epoch 1/150
# 439/439 [==============================] - 194s 367ms/step - loss: 1.0923 - accuracy: 0.6496 - val_loss: 3.8584 - val_accuracy: 0.6254
# Epoch 2/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.9535 - accuracy: 0.6713 - val_loss: 4.7696 - val_accuracy: 0.3400
# Epoch 3/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8933 - accuracy: 0.6817 - val_loss: 0.8864 - val_accuracy: 0.6773
# Epoch 4/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8588 - accuracy: 0.6884 - val_loss: 1.3457 - val_accuracy: 0.3240
# Epoch 5/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8805 - accuracy: 0.6863 - val_loss: 1.3511 - val_accuracy: 0.5988
# Epoch 6/150
# 439/439 [==============================] - 78s 177ms/step - loss: 0.8481 - accuracy: 0.6940 - val_loss: 0.8233 - val_accuracy: 0.6820
# Epoch 7/150
# 439/439 [==============================] - 76s 173ms/step - loss: 0.8320 - accuracy: 0.6926 - val_loss: 1.3556 - val_accuracy: 0.6740
# Epoch 8/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.8102 - accuracy: 0.7061 - val_loss: 0.7167 - val_accuracy: 0.7199
# Epoch 9/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8321 - accuracy: 0.6963 - val_loss: 1403.2410 - val_accuracy: 0.6587
# Epoch 10/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.8567 - accuracy: 0.6944 - val_loss: 2.6684 - val_accuracy: 0.6633
# Epoch 11/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.8333 - accuracy: 0.6961 - val_loss: 0.7504 - val_accuracy: 0.7033
# Epoch 12/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.8154 - accuracy: 0.7037 - val_loss: 0.9771 - val_accuracy: 0.6294
# Epoch 13/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8008 - accuracy: 0.7101 - val_loss: 0.7088 - val_accuracy: 0.7325
# Epoch 14/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.7784 - accuracy: 0.7184 - val_loss: 1.1142 - val_accuracy: 0.6580
# Epoch 15/150
# 439/439 [==============================] - 76s 173ms/step - loss: 0.8089 - accuracy: 0.7071 - val_loss: 0.7560 - val_accuracy: 0.7126
# Epoch 16/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7981 - accuracy: 0.7114 - val_loss: 0.7409 - val_accuracy: 0.7192
# Epoch 17/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.7860 - accuracy: 0.7150 - val_loss: 0.7850 - val_accuracy: 0.7046
# Epoch 18/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.7488 - accuracy: 0.7227 - val_loss: 0.7018 - val_accuracy: 0.7345
# Epoch 19/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.7891 - accuracy: 0.7210 - val_loss: 1905.5228 - val_accuracy: 0.6587
# Epoch 20/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.8012 - accuracy: 0.7070 - val_loss: 0.7797 - val_accuracy: 0.7079
# Epoch 21/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.7803 - accuracy: 0.7146 - val_loss: 40.7867 - val_accuracy: 0.7126
# Epoch 22/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.7514 - accuracy: 0.7254 - val_loss: 2.9674 - val_accuracy: 0.7006
# Epoch 23/150
# 439/439 [==============================] - 76s 173ms/step - loss: 0.7912 - accuracy: 0.7140 - val_loss: 4.8802 - val_accuracy: 0.7259
# Epoch 24/150
# 439/439 [==============================] - 76s 173ms/step - loss: 0.7952 - accuracy: 0.7168 - val_loss: 0.8782 - val_accuracy: 0.6667
# Epoch 25/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.7882 - accuracy: 0.7144 - val_loss: 3.0428 - val_accuracy: 0.1776
# Epoch 26/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.7781 - accuracy: 0.7170 - val_loss: 1.0753 - val_accuracy: 0.6993
# Epoch 27/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7599 - accuracy: 0.7255 - val_loss: 38.0383 - val_accuracy: 0.7179
# Epoch 28/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.7545 - accuracy: 0.7250 - val_loss: 0.6902 - val_accuracy: 0.7452
# Epoch 29/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7614 - accuracy: 0.7228 - val_loss: 0.7099 - val_accuracy: 0.7186
# Epoch 30/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.7951 - accuracy: 0.7207 - val_loss: 17.1348 - val_accuracy: 0.4664
# Epoch 31/150
# 439/439 [==============================] - 76s 173ms/step - loss: 0.8688 - accuracy: 0.6922 - val_loss: 1.2743 - val_accuracy: 0.6707
# Epoch 32/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8330 - accuracy: 0.7061 - val_loss: 1.7171 - val_accuracy: 0.4152
# Epoch 33/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.9087 - accuracy: 0.6790 - val_loss: 0.8246 - val_accuracy: 0.6893
# Epoch 34/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.8439 - accuracy: 0.7009 - val_loss: 0.7542 - val_accuracy: 0.7139
# Epoch 35/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8183 - accuracy: 0.7067 - val_loss: 0.8265 - val_accuracy: 0.7199
# Epoch 36/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8435 - accuracy: 0.7001 - val_loss: 1.4193 - val_accuracy: 0.6933
# Epoch 37/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8343 - accuracy: 0.6997 - val_loss: 1.0291 - val_accuracy: 0.7159
# Epoch 38/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.8282 - accuracy: 0.7034 - val_loss: 0.7992 - val_accuracy: 0.7252
# Epoch 39/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.8064 - accuracy: 0.7076 - val_loss: 0.8486 - val_accuracy: 0.7099
# Epoch 40/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.8082 - accuracy: 0.7070 - val_loss: 0.9348 - val_accuracy: 0.6693
# Epoch 41/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.7968 - accuracy: 0.7076 - val_loss: 2.6351 - val_accuracy: 0.7319
# Epoch 42/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7852 - accuracy: 0.7165 - val_loss: 0.7609 - val_accuracy: 0.7192
# Epoch 43/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8253 - accuracy: 0.7030 - val_loss: 86.1751 - val_accuracy: 0.6627
# Epoch 44/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7809 - accuracy: 0.7197 - val_loss: 11.9888 - val_accuracy: 0.7139
# Epoch 45/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8234 - accuracy: 0.7039 - val_loss: 7.3317 - val_accuracy: 0.6853
# Epoch 46/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7988 - accuracy: 0.7068 - val_loss: 153.1765 - val_accuracy: 0.6680
# Epoch 47/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.8059 - accuracy: 0.7047 - val_loss: 2174.2634 - val_accuracy: 0.6627
# Epoch 48/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.7946 - accuracy: 0.7094 - val_loss: 43.4359 - val_accuracy: 0.6600
# Epoch 49/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8193 - accuracy: 0.7068 - val_loss: 137.4106 - val_accuracy: 0.7166
# Epoch 50/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.8210 - accuracy: 0.7036 - val_loss: 231.4294 - val_accuracy: 0.6354
# Epoch 51/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8344 - accuracy: 0.6996 - val_loss: 43.3419 - val_accuracy: 0.6893
# Epoch 52/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8172 - accuracy: 0.7050 - val_loss: 118.3350 - val_accuracy: 0.7066
# Epoch 53/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.8082 - accuracy: 0.7036 - val_loss: 480.9209 - val_accuracy: 0.6653
# Epoch 54/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7966 - accuracy: 0.7116 - val_loss: 135.7871 - val_accuracy: 0.7239
# Epoch 55/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.8006 - accuracy: 0.7094 - val_loss: 136.6500 - val_accuracy: 0.6926
# Epoch 56/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.7899 - accuracy: 0.7131 - val_loss: 164.9035 - val_accuracy: 0.7252
# Epoch 57/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.7708 - accuracy: 0.7174 - val_loss: 654.1555 - val_accuracy: 0.7112
# Epoch 58/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7695 - accuracy: 0.7224 - val_loss: 97.0194 - val_accuracy: 0.6813
# Epoch 59/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.7826 - accuracy: 0.7138 - val_loss: 2232.7119 - val_accuracy: 0.7079
# Epoch 60/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7655 - accuracy: 0.7210 - val_loss: 331.0284 - val_accuracy: 0.7339
# Epoch 61/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7831 - accuracy: 0.7157 - val_loss: 1.0289 - val_accuracy: 0.6733
# Epoch 62/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8145 - accuracy: 0.7029 - val_loss: 559.0221 - val_accuracy: 0.7039
# Epoch 63/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8171 - accuracy: 0.7070 - val_loss: 487.8708 - val_accuracy: 0.6880
# Epoch 64/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8131 - accuracy: 0.7036 - val_loss: 5355.8311 - val_accuracy: 0.7126
# Epoch 65/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8173 - accuracy: 0.6971 - val_loss: 93.8447 - val_accuracy: 0.7112
# Epoch 66/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.8065 - accuracy: 0.7020 - val_loss: 936.9760 - val_accuracy: 0.7092
# Epoch 67/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.7883 - accuracy: 0.7126 - val_loss: 1529.9049 - val_accuracy: 0.7106
# Epoch 68/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.7735 - accuracy: 0.7148 - val_loss: 1.0105 - val_accuracy: 0.7039
# Epoch 69/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.8053 - accuracy: 0.7040 - val_loss: 12.8731 - val_accuracy: 0.4258
# Epoch 70/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.8186 - accuracy: 0.6977 - val_loss: 7042.9507 - val_accuracy: 0.6853
# Epoch 71/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.8033 - accuracy: 0.7051 - val_loss: 8420.2812 - val_accuracy: 0.7086
# Epoch 72/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.7893 - accuracy: 0.7081 - val_loss: 25327.2363 - val_accuracy: 0.5868
# Epoch 73/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7865 - accuracy: 0.7026 - val_loss: 6432.2734 - val_accuracy: 0.6873
# Epoch 74/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7792 - accuracy: 0.7077 - val_loss: 2032.6932 - val_accuracy: 0.7066
# Epoch 75/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7884 - accuracy: 0.7060 - val_loss: 26382.0137 - val_accuracy: 0.7059
# Epoch 76/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8004 - accuracy: 0.7007 - val_loss: 561.5566 - val_accuracy: 0.6587
# Epoch 77/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8715 - accuracy: 0.6857 - val_loss: 461.0720 - val_accuracy: 0.6780
# Epoch 78/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8725 - accuracy: 0.6813 - val_loss: 484.7101 - val_accuracy: 0.6727
# Epoch 79/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8297 - accuracy: 0.6919 - val_loss: 1157.6045 - val_accuracy: 0.6913
# Epoch 80/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.8088 - accuracy: 0.6937 - val_loss: 1708.6520 - val_accuracy: 0.7152
# Epoch 81/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7936 - accuracy: 0.7024 - val_loss: 288.9033 - val_accuracy: 0.7033
# Epoch 82/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7901 - accuracy: 0.7014 - val_loss: 266.0566 - val_accuracy: 0.7252
# Epoch 83/150
# 439/439 [==============================] - 77s 175ms/step - loss: 0.7829 - accuracy: 0.7098 - val_loss: 1964.6838 - val_accuracy: 0.7139
# Epoch 84/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7902 - accuracy: 0.7148 - val_loss: 5773.0728 - val_accuracy: 0.7319
# Epoch 85/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8457 - accuracy: 0.6929 - val_loss: 179.6140 - val_accuracy: 0.6800
# Epoch 86/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8364 - accuracy: 0.6963 - val_loss: 10855.5898 - val_accuracy: 0.6766
# Epoch 87/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8001 - accuracy: 0.7054 - val_loss: 2525.8010 - val_accuracy: 0.6075
# Epoch 88/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8109 - accuracy: 0.7026 - val_loss: 5673.0767 - val_accuracy: 0.7006
# Epoch 89/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7983 - accuracy: 0.7086 - val_loss: 3872.4172 - val_accuracy: 0.6554
# Epoch 90/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7992 - accuracy: 0.7193 - val_loss: 335.1146 - val_accuracy: 0.7206
# Epoch 91/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7916 - accuracy: 0.7160 - val_loss: 17.3770 - val_accuracy: 0.7132
# Epoch 92/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7711 - accuracy: 0.7181 - val_loss: 992.6584 - val_accuracy: 0.7026
# Epoch 93/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7567 - accuracy: 0.7233 - val_loss: 288.5809 - val_accuracy: 0.7172
# Epoch 94/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7569 - accuracy: 0.7267 - val_loss: 204.5762 - val_accuracy: 0.7339
# Epoch 95/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7816 - accuracy: 0.7148 - val_loss: 18.8442 - val_accuracy: 0.5928
# Epoch 96/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7809 - accuracy: 0.7150 - val_loss: 73.5244 - val_accuracy: 0.7385
# Epoch 97/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7687 - accuracy: 0.7213 - val_loss: 408.2980 - val_accuracy: 0.7299
# Epoch 98/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7840 - accuracy: 0.7151 - val_loss: 682.2350 - val_accuracy: 0.6933
# Epoch 99/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7799 - accuracy: 0.7191 - val_loss: 769.7141 - val_accuracy: 0.6294
# Epoch 100/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.7669 - accuracy: 0.7262 - val_loss: 4364.9312 - val_accuracy: 0.6627
# Epoch 101/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7561 - accuracy: 0.7288 - val_loss: 1.6106 - val_accuracy: 0.7033
# Epoch 102/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7639 - accuracy: 0.7191 - val_loss: 0.7482 - val_accuracy: 0.7285
# Epoch 103/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7768 - accuracy: 0.7214 - val_loss: 325.8861 - val_accuracy: 0.6900
# Epoch 104/150
# 439/439 [==============================] - 76s 172ms/step - loss: 0.8173 - accuracy: 0.7074 - val_loss: 14.4195 - val_accuracy: 0.7112
# Epoch 105/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8054 - accuracy: 0.7077 - val_loss: 13.9942 - val_accuracy: 0.7252
# Epoch 106/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7618 - accuracy: 0.7270 - val_loss: 1.2608 - val_accuracy: 0.7259
# Epoch 107/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7662 - accuracy: 0.7211 - val_loss: 117.5019 - val_accuracy: 0.7292
# Epoch 108/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7744 - accuracy: 0.7230 - val_loss: 30.0489 - val_accuracy: 0.6687
# Epoch 109/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8428 - accuracy: 0.6969 - val_loss: 1183.9813 - val_accuracy: 0.6853
# Epoch 110/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.8027 - accuracy: 0.7057 - val_loss: 1977.0138 - val_accuracy: 0.7332
# Epoch 111/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7894 - accuracy: 0.7080 - val_loss: 470.8855 - val_accuracy: 0.6866
# Epoch 112/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.8007 - accuracy: 0.7113 - val_loss: 432.6830 - val_accuracy: 0.7006
# Epoch 113/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.7803 - accuracy: 0.7141 - val_loss: 24.5413 - val_accuracy: 0.7312
# Epoch 114/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7711 - accuracy: 0.7168 - val_loss: 8761.4795 - val_accuracy: 0.6633
# Epoch 115/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7608 - accuracy: 0.7177 - val_loss: 967.1464 - val_accuracy: 0.7379
# Epoch 116/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7736 - accuracy: 0.7213 - val_loss: 107.3070 - val_accuracy: 0.7292
# Epoch 117/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7520 - accuracy: 0.7298 - val_loss: 565.1611 - val_accuracy: 0.7285
# Epoch 118/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7636 - accuracy: 0.7268 - val_loss: 1827.1700 - val_accuracy: 0.6633
# Epoch 119/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7807 - accuracy: 0.7243 - val_loss: 12.3331 - val_accuracy: 0.6900
# Epoch 120/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7781 - accuracy: 0.7197 - val_loss: 1518.8281 - val_accuracy: 0.6534
# Epoch 121/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7562 - accuracy: 0.7275 - val_loss: 478.6891 - val_accuracy: 0.7099
# Epoch 122/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7477 - accuracy: 0.7288 - val_loss: 949.9327 - val_accuracy: 0.7106
# Epoch 123/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7552 - accuracy: 0.7277 - val_loss: 204.4342 - val_accuracy: 0.7432
# Epoch 124/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7867 - accuracy: 0.7194 - val_loss: 246.7363 - val_accuracy: 0.7312
# Epoch 125/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7761 - accuracy: 0.7225 - val_loss: 1231.9619 - val_accuracy: 0.7199
# Epoch 126/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7651 - accuracy: 0.7244 - val_loss: 140.0750 - val_accuracy: 0.7232
# Epoch 127/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7714 - accuracy: 0.7228 - val_loss: 1367.8109 - val_accuracy: 0.7206
# Epoch 128/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7615 - accuracy: 0.7247 - val_loss: 162.2964 - val_accuracy: 0.7212
# Epoch 129/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7406 - accuracy: 0.7317 - val_loss: 284.1343 - val_accuracy: 0.7265
# Epoch 130/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7622 - accuracy: 0.7268 - val_loss: 2210.3911 - val_accuracy: 0.6946
# Epoch 131/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7629 - accuracy: 0.7288 - val_loss: 137.5841 - val_accuracy: 0.7352
# Epoch 132/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7638 - accuracy: 0.7231 - val_loss: 772.1696 - val_accuracy: 0.7019
# Epoch 133/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7667 - accuracy: 0.7137 - val_loss: 229.7572 - val_accuracy: 0.6900
# Epoch 134/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7647 - accuracy: 0.7220 - val_loss: 419.4581 - val_accuracy: 0.7152
# Epoch 135/150
# 439/439 [==============================] - 74s 169ms/step - loss: 0.7641 - accuracy: 0.7238 - val_loss: 4063.2419 - val_accuracy: 0.7066
# Epoch 136/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7463 - accuracy: 0.7298 - val_loss: 275.8534 - val_accuracy: 0.7372
# Epoch 137/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7610 - accuracy: 0.7284 - val_loss: 1405.2549 - val_accuracy: 0.7246
# Epoch 138/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7437 - accuracy: 0.7268 - val_loss: 17699.5898 - val_accuracy: 0.6374
# Epoch 139/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7323 - accuracy: 0.7344 - val_loss: 2482.8870 - val_accuracy: 0.7299
# Epoch 140/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7309 - accuracy: 0.7311 - val_loss: 6441.2251 - val_accuracy: 0.6401
# Epoch 141/150
# 439/439 [==============================] - 74s 169ms/step - loss: 0.7082 - accuracy: 0.7438 - val_loss: 29417.1211 - val_accuracy: 0.6860
# Epoch 142/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7076 - accuracy: 0.7409 - val_loss: 28247.4199 - val_accuracy: 0.6693
# Epoch 143/150
# 439/439 [==============================] - 75s 170ms/step - loss: 0.7145 - accuracy: 0.7407 - val_loss: 9534.3447 - val_accuracy: 0.5775
# Epoch 144/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7066 - accuracy: 0.7404 - val_loss: 14988.7773 - val_accuracy: 0.6740
# Epoch 145/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.6924 - accuracy: 0.7445 - val_loss: 2589.2263 - val_accuracy: 0.7132
# Epoch 146/150
# 439/439 [==============================] - 75s 172ms/step - loss: 0.7054 - accuracy: 0.7471 - val_loss: 2949.9385 - val_accuracy: 0.7252
# Epoch 147/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7334 - accuracy: 0.7369 - val_loss: 14008.5508 - val_accuracy: 0.6893
# Epoch 148/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7363 - accuracy: 0.7295 - val_loss: 1107.4652 - val_accuracy: 0.7352
# Epoch 149/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7257 - accuracy: 0.7348 - val_loss: 552.4856 - val_accuracy: 0.7106
# Epoch 150/150
# 439/439 [==============================] - 75s 171ms/step - loss: 0.7319 - accuracy: 0.7357 - val_loss: 2734.1006 - val_accuracy: 0.7166

# %%
test_loss, test_accuracy = model.evaluate(test_generator, steps=len(test_generator))
print(f'Test accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 94/94 [==============================] - 25s 271ms/step - loss: 2901.2854 - accuracy: 0.7217
# Test accuracy: 72.17%

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
model.save('New_DenseNet_model.h5')
