# %%
import os
import pandas as pd
import numpy as np
import tensorflow as tf
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.applications import ResNet50
from tensorflow.keras.layers import Dropout, Dense, GlobalAveragePooling2D, Conv2D, BatchNormalization
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.activations import swish
from tensorflow.keras.models import Model
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
df = pd.read_csv("DataSet/HAM.csv")
df['image_id'] = df['image_id'].apply(lambda x: x + ".jpg")
class_counts = df['dx'].value_counts()

# Print the counts for each class
print(class_counts)
# Out:
# dx
# nv       6705
# mel      1113
# bkl      1099
# bcc       514
# akiec     327
# vasc      142
# df        115
# Name: count, dtype: int64

# %%
# Define image dimensions and batch size
img_size = (100, 100)
batch_size = 16

# Create data generators for augmentation
datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)

# %%
train_df, test_valid_df = train_test_split(df, test_size=0.3, random_state=42)
test_df, valid_df = train_test_split(test_valid_df, test_size=0.5, random_state=42)
train_df['image_id'] = 'DataSet/Combined/' + train_df['image_id']
valid_df['image_id'] = 'DataSet/Combined/' + valid_df['image_id']
test_df['image_id'] = 'DataSet/Combined/' + test_df['image_id']

# %%
train_datagen = ImageDataGenerator(
    rescale=1./255,
    rotation_range=20,
    width_shift_range=0.2,
    height_shift_range=0.2,
    horizontal_flip=True,
    zoom_range=0.2
)

valid_datagen = ImageDataGenerator(rescale=1./255)

train_generator = train_datagen.flow_from_dataframe(
    train_df,
    x_col='image_id',
    y_col='dx',
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

valid_generator = valid_datagen.flow_from_dataframe(
    valid_df,
    x_col='image_id',
    y_col='dx',
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)

test_datagen = ImageDataGenerator(rescale=1./255)

test_generator = test_datagen.flow_from_dataframe(
    test_df,
    x_col='image_id',
    y_col='dx',
    target_size=img_size,
    batch_size=batch_size,
    class_mode='categorical'
)
# Out:
# Found 7010 validated image filenames belonging to 7 classes.
# Found 1503 validated image filenames belonging to 7 classes.
# Found 1502 validated image filenames belonging to 7 classes.

# %%
base_model = ResNet50(weights='imagenet', include_top=False, input_shape=(img_size[0], img_size[1], 3))


x = base_model.output
x = Conv2D(64, (3, 3), activation='relu')(x)
x = BatchNormalization()(x)
x = GlobalAveragePooling2D()(x)

x = Dropout(0.5)(x)
x = Dense(1024, activation=swish)(x)
x = Dropout(0.5)(x)
x = Dense(256, activation=swish)(x)
x = Dropout(0.5)(x)

predictions = Dense(7, activation='softmax')(x)  # Replace NUM_CLASSES with the number of classes

model = Model(inputs=base_model.input, outputs=predictions)

# %%
model.compile(optimizer=Adam(learning_rate=0.001), loss='categorical_crossentropy', metrics=['accuracy'])

# %%
history = model.fit(
    train_generator,
    validation_data=valid_generator,
    epochs=150,  # You can adjust the number of epochs
    steps_per_epoch=len(train_generator),
    validation_steps=len(valid_generator)
)
# Out:
# Epoch 1/150
# 439/439 [==============================] - 68s 134ms/step - loss: 1.1121 - accuracy: 0.6525 - val_loss: 2.2774 - val_accuracy: 0.1011
# Epoch 2/150
# 439/439 [==============================] - 56s 127ms/step - loss: 1.0097 - accuracy: 0.6685 - val_loss: 1.0321 - val_accuracy: 0.6574
# Epoch 3/150
# 439/439 [==============================] - 56s 127ms/step - loss: 0.9964 - accuracy: 0.6688 - val_loss: 1.1495 - val_accuracy: 0.6587
# Epoch 4/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.9808 - accuracy: 0.6660 - val_loss: 5.7672 - val_accuracy: 0.6494
# Epoch 5/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.9420 - accuracy: 0.6718 - val_loss: 1.2125 - val_accuracy: 0.6713
# Epoch 6/150
# 439/439 [==============================] - 56s 127ms/step - loss: 0.9220 - accuracy: 0.6753 - val_loss: 1.3531 - val_accuracy: 0.6587
# Epoch 7/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.9369 - accuracy: 0.6759 - val_loss: 1.2055 - val_accuracy: 0.5203
# Epoch 8/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.9195 - accuracy: 0.6733 - val_loss: 0.8748 - val_accuracy: 0.6760
# Epoch 9/150
# 439/439 [==============================] - 56s 127ms/step - loss: 0.9104 - accuracy: 0.6753 - val_loss: 1.1186 - val_accuracy: 0.6700
# Epoch 10/150
# 439/439 [==============================] - 56s 127ms/step - loss: 0.9071 - accuracy: 0.6769 - val_loss: 1.7786 - val_accuracy: 0.6667
# Epoch 11/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.8866 - accuracy: 0.6833 - val_loss: 0.8434 - val_accuracy: 0.6973
# Epoch 12/150
# 439/439 [==============================] - 56s 127ms/step - loss: 0.8900 - accuracy: 0.6793 - val_loss: 0.9162 - val_accuracy: 0.6793
# Epoch 13/150
# 439/439 [==============================] - 56s 127ms/step - loss: 0.8589 - accuracy: 0.6919 - val_loss: 1.2176 - val_accuracy: 0.4817
# Epoch 14/150
# 439/439 [==============================] - 56s 127ms/step - loss: 0.8687 - accuracy: 0.6853 - val_loss: 1.1129 - val_accuracy: 0.6161
# Epoch 15/150
# 439/439 [==============================] - 56s 127ms/step - loss: 0.8991 - accuracy: 0.6797 - val_loss: 0.8987 - val_accuracy: 0.6926
# Epoch 16/150
# 439/439 [==============================] - 56s 127ms/step - loss: 0.8599 - accuracy: 0.6856 - val_loss: 0.9288 - val_accuracy: 0.6647
# Epoch 17/150
# 439/439 [==============================] - 56s 127ms/step - loss: 0.8611 - accuracy: 0.6917 - val_loss: 0.8168 - val_accuracy: 0.7013
# Epoch 18/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.8368 - accuracy: 0.6923 - val_loss: 0.8639 - val_accuracy: 0.6727
# Epoch 19/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.8345 - accuracy: 0.6932 - val_loss: 0.7961 - val_accuracy: 0.6966
# Epoch 20/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.8185 - accuracy: 0.6936 - val_loss: 1.3656 - val_accuracy: 0.6627
# Epoch 21/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.8100 - accuracy: 0.7000 - val_loss: 1.8435 - val_accuracy: 0.1923
# Epoch 22/150
# 439/439 [==============================] - 56s 127ms/step - loss: 0.8255 - accuracy: 0.6971 - val_loss: 0.8333 - val_accuracy: 0.6979
# Epoch 23/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7979 - accuracy: 0.6999 - val_loss: 0.9796 - val_accuracy: 0.6766
# Epoch 24/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.8174 - accuracy: 0.7050 - val_loss: 0.8555 - val_accuracy: 0.6833
# Epoch 25/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.8278 - accuracy: 0.7040 - val_loss: 0.7522 - val_accuracy: 0.7246
# Epoch 26/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.8466 - accuracy: 0.6963 - val_loss: 1.2493 - val_accuracy: 0.4877
# Epoch 27/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.8244 - accuracy: 0.7013 - val_loss: 1.4442 - val_accuracy: 0.6653
# Epoch 28/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7968 - accuracy: 0.7057 - val_loss: 1.0095 - val_accuracy: 0.6720
# Epoch 29/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7936 - accuracy: 0.7117 - val_loss: 1.2500 - val_accuracy: 0.6660
# Epoch 30/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7858 - accuracy: 0.7126 - val_loss: 0.7654 - val_accuracy: 0.7159
# Epoch 31/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7895 - accuracy: 0.7121 - val_loss: 0.7976 - val_accuracy: 0.7172
# Epoch 32/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7813 - accuracy: 0.7164 - val_loss: 1.9802 - val_accuracy: 0.1384
# Epoch 33/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7755 - accuracy: 0.7164 - val_loss: 0.7741 - val_accuracy: 0.7006
# Epoch 34/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7874 - accuracy: 0.7081 - val_loss: 0.8618 - val_accuracy: 0.6773
# Epoch 35/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.8363 - accuracy: 0.7006 - val_loss: 0.8887 - val_accuracy: 0.6700
# Epoch 36/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7937 - accuracy: 0.7121 - val_loss: 0.8615 - val_accuracy: 0.6900
# Epoch 37/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7835 - accuracy: 0.7187 - val_loss: 5.3999 - val_accuracy: 0.6587
# Epoch 38/150
# 439/439 [==============================] - 56s 127ms/step - loss: 0.8101 - accuracy: 0.7053 - val_loss: 0.7783 - val_accuracy: 0.7026
# Epoch 39/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.7543 - accuracy: 0.7237 - val_loss: 0.9481 - val_accuracy: 0.6248
# Epoch 40/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7460 - accuracy: 0.7260 - val_loss: 0.7295 - val_accuracy: 0.7359
# Epoch 41/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7365 - accuracy: 0.7260 - val_loss: 0.7071 - val_accuracy: 0.7452
# Epoch 42/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7453 - accuracy: 0.7295 - val_loss: 0.7199 - val_accuracy: 0.7272
# Epoch 43/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7389 - accuracy: 0.7314 - val_loss: 0.7008 - val_accuracy: 0.7445
# Epoch 44/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7294 - accuracy: 0.7324 - val_loss: 0.7427 - val_accuracy: 0.7279
# Epoch 45/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.7210 - accuracy: 0.7322 - val_loss: 0.7122 - val_accuracy: 0.7425
# Epoch 46/150
# 439/439 [==============================] - 84s 192ms/step - loss: 0.7113 - accuracy: 0.7355 - val_loss: 1.2611 - val_accuracy: 0.6707
# Epoch 47/150
# 439/439 [==============================] - 109s 248ms/step - loss: 0.7116 - accuracy: 0.7335 - val_loss: 0.8836 - val_accuracy: 0.6793
# Epoch 48/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.7155 - accuracy: 0.7362 - val_loss: 0.8050 - val_accuracy: 0.7126
# Epoch 49/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.6996 - accuracy: 0.7428 - val_loss: 0.9807 - val_accuracy: 0.6800
# Epoch 50/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.7196 - accuracy: 0.7382 - val_loss: 0.7559 - val_accuracy: 0.7232
# Epoch 51/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.7008 - accuracy: 0.7417 - val_loss: 0.8890 - val_accuracy: 0.7026
# Epoch 52/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.6913 - accuracy: 0.7438 - val_loss: 1.0203 - val_accuracy: 0.6946
# Epoch 53/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.6975 - accuracy: 0.7428 - val_loss: 1.1740 - val_accuracy: 0.5096
# Epoch 54/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6933 - accuracy: 0.7461 - val_loss: 1.3400 - val_accuracy: 0.6707
# Epoch 55/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6840 - accuracy: 0.7488 - val_loss: 0.9084 - val_accuracy: 0.6407
# Epoch 56/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6963 - accuracy: 0.7455 - val_loss: 0.7997 - val_accuracy: 0.6853
# Epoch 57/150
# 439/439 [==============================] - 56s 129ms/step - loss: 0.6803 - accuracy: 0.7499 - val_loss: 0.8506 - val_accuracy: 0.7013
# Epoch 58/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.6690 - accuracy: 0.7581 - val_loss: 1.3180 - val_accuracy: 0.6760
# Epoch 59/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6737 - accuracy: 0.7506 - val_loss: 0.9560 - val_accuracy: 0.6101
# Epoch 60/150
# 439/439 [==============================] - 58s 133ms/step - loss: 0.6799 - accuracy: 0.7516 - val_loss: 0.6389 - val_accuracy: 0.7545
# Epoch 61/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6752 - accuracy: 0.7515 - val_loss: 0.8326 - val_accuracy: 0.7172
# Epoch 62/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.6585 - accuracy: 0.7562 - val_loss: 1.7238 - val_accuracy: 0.6733
# Epoch 63/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6726 - accuracy: 0.7529 - val_loss: 0.6926 - val_accuracy: 0.7339
# Epoch 64/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.6870 - accuracy: 0.7476 - val_loss: 0.8598 - val_accuracy: 0.6720
# Epoch 65/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6724 - accuracy: 0.7531 - val_loss: 0.6277 - val_accuracy: 0.7598
# Epoch 66/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6501 - accuracy: 0.7578 - val_loss: 0.6252 - val_accuracy: 0.7665
# Epoch 67/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.6526 - accuracy: 0.7566 - val_loss: 0.9601 - val_accuracy: 0.7099
# Epoch 68/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6288 - accuracy: 0.7703 - val_loss: 0.6747 - val_accuracy: 0.7545
# Epoch 69/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6323 - accuracy: 0.7700 - val_loss: 0.6350 - val_accuracy: 0.7705
# Epoch 70/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.6416 - accuracy: 0.7705 - val_loss: 0.7489 - val_accuracy: 0.7525
# Epoch 71/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.6288 - accuracy: 0.7696 - val_loss: 0.8451 - val_accuracy: 0.7312
# Epoch 72/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.6330 - accuracy: 0.7649 - val_loss: 0.7250 - val_accuracy: 0.7232
# Epoch 73/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6296 - accuracy: 0.7672 - val_loss: 0.8763 - val_accuracy: 0.7239
# Epoch 74/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.6441 - accuracy: 0.7702 - val_loss: 0.7688 - val_accuracy: 0.7013
# Epoch 75/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6323 - accuracy: 0.7659 - val_loss: 1.0564 - val_accuracy: 0.6979
# Epoch 76/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.6220 - accuracy: 0.7740 - val_loss: 0.6297 - val_accuracy: 0.7651
# Epoch 77/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.6239 - accuracy: 0.7720 - val_loss: 0.7889 - val_accuracy: 0.6979
# Epoch 78/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.6120 - accuracy: 0.7833 - val_loss: 0.7053 - val_accuracy: 0.7239
# Epoch 79/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6182 - accuracy: 0.7729 - val_loss: 1.4262 - val_accuracy: 0.6766
# Epoch 80/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.6465 - accuracy: 0.7656 - val_loss: 1.3096 - val_accuracy: 0.6766
# Epoch 81/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.6208 - accuracy: 0.7810 - val_loss: 0.6668 - val_accuracy: 0.7492
# Epoch 82/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.6211 - accuracy: 0.7769 - val_loss: 0.6424 - val_accuracy: 0.7658
# Epoch 83/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6190 - accuracy: 0.7787 - val_loss: 0.7955 - val_accuracy: 0.6939
# Epoch 84/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.6148 - accuracy: 0.7785 - val_loss: 0.7185 - val_accuracy: 0.7252
# Epoch 85/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6048 - accuracy: 0.7767 - val_loss: 1.9208 - val_accuracy: 0.6733
# Epoch 86/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.5981 - accuracy: 0.7836 - val_loss: 0.9236 - val_accuracy: 0.6440
# Epoch 87/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6062 - accuracy: 0.7866 - val_loss: 4.8001 - val_accuracy: 0.6580
# Epoch 88/150
# 439/439 [==============================] - 58s 132ms/step - loss: 0.6077 - accuracy: 0.7836 - val_loss: 1.0294 - val_accuracy: 0.7046
# Epoch 89/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.6132 - accuracy: 0.7822 - val_loss: 0.6471 - val_accuracy: 0.7611
# Epoch 90/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5863 - accuracy: 0.7876 - val_loss: 0.7599 - val_accuracy: 0.7259
# Epoch 91/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5869 - accuracy: 0.7845 - val_loss: 0.9982 - val_accuracy: 0.7059
# Epoch 92/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5728 - accuracy: 0.7886 - val_loss: 0.8738 - val_accuracy: 0.6873
# Epoch 93/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.5847 - accuracy: 0.7899 - val_loss: 1.1310 - val_accuracy: 0.6939
# Epoch 94/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.5803 - accuracy: 0.7913 - val_loss: 0.7716 - val_accuracy: 0.7558
# Epoch 95/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.5808 - accuracy: 0.7890 - val_loss: 0.8673 - val_accuracy: 0.7405
# Epoch 96/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.5776 - accuracy: 0.7893 - val_loss: 0.6899 - val_accuracy: 0.7425
# Epoch 97/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5708 - accuracy: 0.7984 - val_loss: 1.0167 - val_accuracy: 0.7112
# Epoch 98/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.5661 - accuracy: 0.7904 - val_loss: 0.9843 - val_accuracy: 0.6613
# Epoch 99/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5597 - accuracy: 0.7996 - val_loss: 0.7354 - val_accuracy: 0.7292
# Epoch 100/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5683 - accuracy: 0.7974 - val_loss: 0.6466 - val_accuracy: 0.7565
# Epoch 101/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.5577 - accuracy: 0.7909 - val_loss: 1.5229 - val_accuracy: 0.6420
# Epoch 102/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5544 - accuracy: 0.7966 - val_loss: 0.6575 - val_accuracy: 0.7319
# Epoch 103/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5558 - accuracy: 0.7991 - val_loss: 1.7930 - val_accuracy: 0.3752
# Epoch 104/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.5616 - accuracy: 0.8027 - val_loss: 0.7908 - val_accuracy: 0.7452
# Epoch 105/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.5437 - accuracy: 0.8023 - val_loss: 0.7836 - val_accuracy: 0.7452
# Epoch 106/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.5447 - accuracy: 0.8070 - val_loss: 0.7390 - val_accuracy: 0.7119
# Epoch 107/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.5482 - accuracy: 0.8011 - val_loss: 0.6485 - val_accuracy: 0.7711
# Epoch 108/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5436 - accuracy: 0.8019 - val_loss: 1.8651 - val_accuracy: 0.6747
# Epoch 109/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5335 - accuracy: 0.8093 - val_loss: 1.0316 - val_accuracy: 0.7139
# Epoch 110/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5305 - accuracy: 0.8043 - val_loss: 2.1957 - val_accuracy: 0.6580
# Epoch 111/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5373 - accuracy: 0.8090 - val_loss: 1.2727 - val_accuracy: 0.6946
# Epoch 112/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.5181 - accuracy: 0.8078 - val_loss: 0.7932 - val_accuracy: 0.7206
# Epoch 113/150
# 439/439 [==============================] - 56s 128ms/step - loss: 0.5295 - accuracy: 0.8136 - val_loss: 0.7265 - val_accuracy: 0.7525
# Epoch 114/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5181 - accuracy: 0.8098 - val_loss: 0.8627 - val_accuracy: 0.7279
# Epoch 115/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5251 - accuracy: 0.8080 - val_loss: 1.3003 - val_accuracy: 0.7112
# Epoch 116/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5292 - accuracy: 0.8096 - val_loss: 0.8044 - val_accuracy: 0.7452
# Epoch 117/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5341 - accuracy: 0.8070 - val_loss: 1.1863 - val_accuracy: 0.6959
# Epoch 118/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5236 - accuracy: 0.8130 - val_loss: 1.4672 - val_accuracy: 0.6873
# Epoch 119/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5173 - accuracy: 0.8181 - val_loss: 0.6590 - val_accuracy: 0.7631
# Epoch 120/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.5190 - accuracy: 0.8113 - val_loss: 0.9882 - val_accuracy: 0.7312
# Epoch 121/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.4992 - accuracy: 0.8168 - val_loss: 0.8845 - val_accuracy: 0.7259
# Epoch 122/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.5044 - accuracy: 0.8181 - val_loss: 0.8948 - val_accuracy: 0.7392
# Epoch 123/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.5033 - accuracy: 0.8252 - val_loss: 1.8116 - val_accuracy: 0.4631
# Epoch 124/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.5115 - accuracy: 0.8114 - val_loss: 1.2276 - val_accuracy: 0.7073
# Epoch 125/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.5041 - accuracy: 0.8203 - val_loss: 1.1703 - val_accuracy: 0.5788
# Epoch 126/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.4909 - accuracy: 0.8241 - val_loss: 0.8656 - val_accuracy: 0.7319
# Epoch 127/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.4900 - accuracy: 0.8265 - val_loss: 0.8201 - val_accuracy: 0.7545
# Epoch 128/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.4794 - accuracy: 0.8267 - val_loss: 0.9665 - val_accuracy: 0.7186
# Epoch 129/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.4750 - accuracy: 0.8305 - val_loss: 0.8015 - val_accuracy: 0.7485
# Epoch 130/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.4953 - accuracy: 0.8261 - val_loss: 3.8996 - val_accuracy: 0.4824
# Epoch 131/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.4599 - accuracy: 0.8365 - val_loss: 0.9463 - val_accuracy: 0.7312
# Epoch 132/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.4750 - accuracy: 0.8285 - val_loss: 0.7872 - val_accuracy: 0.7379
# Epoch 133/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.4722 - accuracy: 0.8331 - val_loss: 0.9458 - val_accuracy: 0.7279
# Epoch 134/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.4618 - accuracy: 0.8368 - val_loss: 0.7106 - val_accuracy: 0.7478
# Epoch 135/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.4723 - accuracy: 0.8314 - val_loss: 0.8803 - val_accuracy: 0.7352
# Epoch 136/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.4581 - accuracy: 0.8377 - val_loss: 1.2269 - val_accuracy: 0.6633
# Epoch 137/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.4795 - accuracy: 0.8320 - val_loss: 0.8451 - val_accuracy: 0.7438
# Epoch 138/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.4597 - accuracy: 0.8344 - val_loss: 1.2341 - val_accuracy: 0.7259
# Epoch 139/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.4587 - accuracy: 0.8364 - val_loss: 0.8396 - val_accuracy: 0.7033
# Epoch 140/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.4494 - accuracy: 0.8408 - val_loss: 0.6696 - val_accuracy: 0.7858
# Epoch 141/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.4451 - accuracy: 0.8402 - val_loss: 1.4000 - val_accuracy: 0.7152
# Epoch 142/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.4523 - accuracy: 0.8399 - val_loss: 0.9708 - val_accuracy: 0.7132
# Epoch 143/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.4452 - accuracy: 0.8415 - val_loss: 0.7000 - val_accuracy: 0.7931
# Epoch 144/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.4400 - accuracy: 0.8459 - val_loss: 1.0378 - val_accuracy: 0.6374
# Epoch 145/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.4416 - accuracy: 0.8404 - val_loss: 1.7291 - val_accuracy: 0.6979
# Epoch 146/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.4375 - accuracy: 0.8471 - val_loss: 0.6672 - val_accuracy: 0.7738
# Epoch 147/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.4391 - accuracy: 0.8456 - val_loss: 1.0435 - val_accuracy: 0.6906
# Epoch 148/150
# 439/439 [==============================] - 57s 129ms/step - loss: 0.4287 - accuracy: 0.8471 - val_loss: 1.2224 - val_accuracy: 0.7385
# Epoch 149/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.4296 - accuracy: 0.8439 - val_loss: 2.2628 - val_accuracy: 0.4385
# Epoch 150/150
# 439/439 [==============================] - 57s 130ms/step - loss: 0.4167 - accuracy: 0.8544 - val_loss: 0.9473 - val_accuracy: 0.7525

# %%
test_loss, test_accuracy = model.evaluate(test_generator, steps=len(test_generator))
print(f'Test accuracy: {test_accuracy * 100:.2f}%')
# Out:
# 94/94 [==============================] - 21s 228ms/step - loss: 0.9438 - accuracy: 0.7630
# Test accuracy: 76.30%

# %%
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

# Plot training and validation loss
plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# %%
model.save('Neww_resnet18_model.h5')
